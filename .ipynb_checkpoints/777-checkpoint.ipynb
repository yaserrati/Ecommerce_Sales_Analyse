# %%
import pandas as pd

# %%
df= pd.read_csv("ecommerce-data-with-anomalies.csv")

# %%
df.head()
# Out:
#    ID                Name  Age Gender         City             Country
# 0   0    Elizabeth Harris   42      F    Chungberg  Mismatched Country  \
# 1   1        Michele Best   72      M  Port Sergio               Egypt
# 2   2         Jake Taylor   -5      M   Evansmouth      Czech Republic
# 3   3  Christian Curry MD   64      M   Jensenfurt   Brunei Darussalam
# 4   4         Craig Jones   92      M   East Jerry   Wallis and Futuna
#
#          CreditCard                                        FullAddress
# 0  2227218447017949  75874 Chad Mountain Suite 588, West Robertches...  \
# 1  2556439104848944  4039 David Fords Apt. 678, Lake Christopherber...
# 2  2273966520760545  748 Mendez Ridges Apt. 994, Lake Jonathanton, ...
# 3  2238348117052863             735 Jones Mews, New Ginafurt, AR 99785
# 4  2225629684025639         95949 Jill Circle, Tuckerchester, VI 49522
#
#   UserSignUpDate UserLastPurchaseDate  ... UserLastLoginDate
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     1500 non-null   int64
#  1   Name                   1500 non-null   object
#  2   Age                    1500 non-null   int64
#  3   Gender                 1500 non-null   object
#  4   City                   1500 non-null   object
#  5   Country                1500 non-null   object
#  6   CreditCard             1500 non-null   int64
#  7   FullAddress            1500 non-null   object
#  8   UserSignUpDate         1500 non-null   object
#  9   UserLastPurchaseDate   1500 non-null   object
#  10  UserStatus             1500 non-null   object
#  11  UserTotalPurchases     1500 non-null   int64
#  12  UserSegment            1500 non-null   object
#  13  UserLocation           1500 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# ID                        0
# Name                      0
# Age                       0
# Gender                    0
# City                      0
# Country                   0
# CreditCard                0
# FullAddress               0
# UserSignUpDate            0
# UserLastPurchaseDate      0
# UserStatus                0
# UserTotalPurchases        0
# UserSegment               0
# UserLocation              0
# UserSourceType            0
# UserLastLoginDate         0
# UserPurchaseFrequency     0
# Product Name             75
# Category                  0
# Subcategory               0
# Price                     0
# Date_Purchase             0
# Quantity                  0
# Rating                    0
# Comment                   0
# dtype: int64

# %%
df.shape
# Out:
# (1500, 25)

# %%
df.describe()
# Out:
#                 ID          Age    CreditCard  UserTotalPurchases       Price
# count  1500.000000  1500.000000  1.500000e+03         1500.000000  1500.00000  \
# mean    749.500000    67.985333  3.117282e+15            7.947333   232.60600
# std     433.157015    63.934306  1.271170e+15            4.368671   347.58012
# min       0.000000    -5.000000  2.221014e+15            1.000000  -100.00000
# 25%     374.750000     3.000000  2.266936e+15            4.000000   -48.00000
# 50%     749.500000    53.500000  2.462863e+15            8.000000    19.00000
# 75%    1124.250000   150.000000  2.720815e+15           12.000000   502.00000
# max    1499.000000   150.000000  5.596755e+15           15.000000  1000.00000
#
#           Quantity       Rating
# count  1500.000000  1500.000000
# mean      1.470000     2.538000
# std       4.652117     2.312601
# min      -5.000000    -1.000000
# 25%      -2.000000     1.000000
# 50%       1.000000     2.000000
# 75%       5.000000     5.000000
# ...

# %%
Subcategory
Price
Date_Purchase
Quantity
Rating
Comment

# %%
df.sample(15)
# Out:
#         ID                 Name  Age Gender                City
# 94      94        Brian Sanchez  150      F           Ayalaview  \
# 1393  1393  Timothy Robinson MD   -3      F          Brianmouth
# 1266  1266         Jessica Cobb   35      M         Bentonshire
# 568    568          Jared Smith    5      F         Sheliamouth
# 925    925          Sara Norman   34      F          Port Bruce
# 1316  1316    Catherine Carroll  150      F            Ryanstad
# 421    421       Connor Frazier   62      F         Lake Daniel
# 73      73       Kenneth Barton   89      M  East Jennifershire
# 581    581     Katelyn Gonzalez    2      M   North Jillchester
# 119    119         Michael West   76      M          Kelseyside
# 1250  1250       Michael Harris   92      M         Aguilarfort
# 1343  1343        Robert Holmes  150      M            Ballland
# 956    956     Darlene Williams    2      M       South Jeffery
# 97      97        Gavin Collins   60      F      North Toddberg
# ...

# %% [markdown]
# ## 1- rating and quantity and price are negative so we can to remplace by valuer absolute or drop
# ## 2- date_purchase date type
# ## 3 - 112 rows has 0 in  comumn Quantity

# %%
df.Category.unique()
# Out:
# array(['Furniture', 'Grocery', 'Books', 'Clothing', 'Electronics'],
#       dtype=object)

# %%
result = df.loc[df['Price'] == 0]

# %%
result = df.loc[df['Quantity'] == 0]

# %%
result
# Out:
#         ID                Name  Age Gender         City
# 3        3  Christian Curry MD   64      M   Jensenfurt  \
# 15      15         Thomas Wang   44      F  Port Nicole
# 16      16        Kevin Obrien    3      M     Penaside
# 54      54  Bradley Pennington   73      F  South Billy
# 57      57        Brandon Lowe    3      M  Michaelberg
# ...    ...                 ...  ...    ...          ...
# 1441  1441        Jacob Morris  150      M     Mossport
# 1454  1454      Kevin Williams  150      M   Dianeshire
# 1466  1466      Daniel Johnson   68      F  New Jessica
# 1480  1480          Jose Owens   26      F   Nicolefort
# 1498  1498        Scott Wilson    2      F   Johnnyberg
#
#                      Country        CreditCard
# 3          Brunei Darussalam  2238348117052863  \
# 15                      Peru  2419812079340443
# 16    Bosnia and Herzegovina  2293893566103974
# 54                   Bahamas  2277355918628827
# 57               Switzerland  2245712997903241
# ...
